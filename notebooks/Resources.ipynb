# %%
# !pip install GitPython

# %%
import subprocess
import os
import git
import requests

import pandas as pd

import requests
from bs4 import BeautifulSoup

import json

# %% [markdown]
# ### Reading Crisp framework

# %%
from IPython.display import IFrame, display
#filepath = "http://wikipedia.org" # works with websites too!
filepath = "../data/Images/CrispFramework.PNG"
IFrame(filepath, width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="../data/Images/CrispFramework.PNG"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Business Understanding
#
# We would like to track the spread of Coronavirus across countries to stop the spread and inform the general public.

# %% [markdown]
# ### Data Understanding
#
#  - John Hopkins Github Data https://github.com/CSSEGISandData/COVID-19.git
#  - REST API services to retrieve Data www.smartable.ai

# %% [markdown]
# ### Github Data

# %%
# Approach 1

# # automating the pull of the data after cloning

# github_pull = subprocess.Popen("/usr/bin/git pull",
#                            cwd = os.path.dirname('../data/raw/COVID-19/'),
#                            shell = True,
#                            stdout = subprocess.PIPE,
#                            stderr = subprocess.PIPE)
# (out,error) = github_pull.communicate()

# print("Error:"+str(error))
# print("out:"+str(out))
# Out:
# Error:b'The system cannot find the path specified.\r\n'
# out:b''

# %%
# Approach 2

# automating the pull of the data after cloning

github_pull = git.cmd.Git('../data/raw/COVID-19/')
github_pull.pull()
# Out:
# 'Already up to date.'

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/4/21  2/5/21  2/6/21  2/7/21  \
# 0        0        0        0        0  ...   55231   55265   55330   55335
# 1        0        0        0        0  ...   81993   83082   84212   85336
# 2        0        0        0        0  ...  108381  108629  108629  109088
# 3        0        0        0        0  ...   10137   10172   10206   10251
# 4        0        0        0        0  ...   19996   20030   20062   20086
#
#    2/8/21  2/9/21  2/10/21  2/11/21  2/12/21  2/13/21
# ...

# %% [markdown]
# ### REST API Data
# www.smartable.ai

# %%
# getting data from API

url = "https://coronavirus-smartable.p.rapidapi.com/stats/v1/CA/"

headers = {
    'x-rapidapi-key': "572e4af04cmsh3c40e9f74b8b78ap1146f4jsn75ead2590b80",
    'x-rapidapi-host': "coronavirus-smartable.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
CA_dict=json.loads(response.content) # imports string
with open('../data/raw/SMARTABLE/CA_data.txt', 'w') as outfile:
    json.dump(CA_dict, outfile,indent=2)

# %%
print(json.dumps(CA_dict,indent=2)) #string dump
# Out:
# {
#   "location": {
#     "long": -106.346771,
#     "countryOrRegion": "Canada",
#     "provinceOrState": null,
#     "county": null,
#     "isoCode": "CA",
#     "lat": 56.130366
#   },
#   "updatedDateTime": "2021-02-10T19:58:25.1634741Z",
#   "stats": {
#     "totalConfirmedCases": 817219,
#     "newlyConfirmedCases": 1731,
#     "totalDeaths": 20970,
#     "newDeaths": 56,
#     "totalRecoveredCases": 765757,
#     "newlyRecoveredCases": 959,
#     "history": [
#       {
#         "date": "2020-01-22T00:00:00",
#         "confirmed": 0,
#         "deaths": 0,
#         "recovered": 0
#       },
#       {
#         "date": "2020-01-23T00:00:00",
#         "confirmed": 0,
#         "deaths": 0,
#         "recovered": 0
#       },
#       {
#         "date": "2020-01-24T00:00:00",
#         "confirmed": 0,
#         "deaths": 0,
#         "recovered": 0
#       },
#       {
#         "date": "2020-01-25T00:00:00",
#         "confirmed": 0,
#         "deaths": 0,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-f53541d0960a> in <module>
#       1 x= response.json()
#       2 x.keys()
# ----> 3 df = pd.DataFrame(x['stats'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
# ...

# %%
df.head()
# Out:
#          long countryOrRegion provinceOrState county isoCode        lat
# 0 -106.346771          Canada            None   None      CA  56.130366
